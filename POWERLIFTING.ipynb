# %%
import pandas as pd
import numpy as np
df=pd.read_csv('openpowerlifting-2024-01-06-4c732975.csv')
df
# Out:
# C:\Users\Gahtan Syarif Nahdi\AppData\Local\Temp\ipykernel_7968\181351552.py:3: DtypeWarning: Columns (31,33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('openpowerlifting-2024-01-06-4c732975.csv')
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 3043008            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 3043009             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 3043010   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# ...

# %%
df=df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 3039407            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 3039408             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 3039409   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# 3039410            Kelly Phasey   F   SBD  Single-ply  39.5    35-39
# 3039411  Hildeborg Juvet Hugdal   F   SBD  Single-ply  32.5    24-34
#
#         BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# ...

# %%
df['Sex'] = df['Sex'].apply(lambda x: 'Male' if x == 'M' else ('Female' if x == 'F' else ('Non-Binary' if x == 'Mx' else None)))

# %%
df['Sex']
# Out:
# 0          Female
# 1          Female
# 2            Male
# 3            Male
# 4            Male
#             ...
# 3039407    Female
# 3039408    Female
# 3039409    Female
# 3039410    Female
# 3039411    Female
# Name: Sex, Length: 3039412, dtype: object

# %%
df.describe()
# Out:
#                 Age  BodyweightKg       Squat1Kg       Squat2Kg  \
# count  1.970436e+06  3.001066e+06  904359.000000  895127.000000
# mean   3.075822e+01  8.416584e+01     115.342974      99.536105
# std    1.321159e+01  2.262588e+01     136.387166     160.343024
# min    0.000000e+00  1.000000e+01    -555.000000    -580.000000
# 25%    2.050000e+01  6.720000e+01      90.000000      80.000000
# 50%    2.750000e+01  8.195000e+01     145.000000     145.500000
# 75%    3.850000e+01  9.879000e+01     197.500000     202.500000
# max    9.800000e+01  3.000000e+02     555.000000     577.500000
#
#             Squat3Kg     Squat4Kg  Best3SquatKg      Bench1Kg      Bench2Kg  \
# count  871241.000000  8432.000000  2.032094e+06  1.388744e+06  1.373156e+06
# mean       41.044888    77.079366  1.744581e+02  8.363560e+01  5.756738e+01
# std       190.330192   179.617147  6.837237e+01  9.791479e+01  1.226899e+02
# min      -600.500000  -550.000000 -5.080200e+02 -6.355000e+02 -6.355000e+02
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
#        'Goodlift', 'Tested', 'Country', 'State', 'Federation',
#        'ParentFederation', 'Date', 'MeetCountry', 'MeetState', 'MeetTown',
#        'MeetName'],
#       dtype='object')

# %%
df=df[['Name','Sex','Event','Equipment','Age','TotalKg','Dots','Tested','Country','Federation','Date']]
df
# Out:
#                            Name     Sex Event   Equipment   Age  TotalKg  \
# 0                   Alona Vladi  Female   SBD         Raw  33.0    247.5
# 1            Galina Solovyanova  Female   SBD         Raw  43.0    282.5
# 2                Daniil Voronin    Male   SBD         Raw  15.5    267.5
# 3                Aleksey Krasov    Male   SBD         Raw  35.0    430.0
# 4        Margarita Pleschenkova    Male   SBD         Raw  26.5    265.0
# ...                         ...     ...   ...         ...   ...      ...
# 3039407            Inna Orobets  Female   SBD  Single-ply  45.0    645.0
# 3039408             Ágnes Szabó  Female   SBD  Single-ply  27.5    632.5
# 3039409   Brenda van der Meulen  Female   SBD  Single-ply  37.5    617.5
# 3039410            Kelly Phasey  Female   SBD  Single-ply  39.5    515.0
# 3039411  Hildeborg Juvet Hugdal  Female   SBD  Single-ply  32.5      NaN
#
#            Dots Tested      Country Federation        Date
# ...

# %%
df.dtypes
# Out:
# Name           object
# Sex            object
# Event          object
# Equipment      object
# Age           float64
# TotalKg       float64
# Dots          float64
# Tested         object
# Country        object
# Federation     object
# Date           object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
# C:\Users\Gahtan Syarif Nahdi\AppData\Local\Temp\ipykernel_7968\66253117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
#                            Name     Sex Event   Equipment   Age  TotalKg  \
# 0                   Alona Vladi  Female   SBD         Raw  33.0    247.5
# 1            Galina Solovyanova  Female   SBD         Raw  43.0    282.5
# 2                Daniil Voronin    Male   SBD         Raw  15.5    267.5
# 3                Aleksey Krasov    Male   SBD         Raw  35.0    430.0
# 4        Margarita Pleschenkova    Male   SBD         Raw  26.5    265.0
# ...                         ...     ...   ...         ...   ...      ...
# ...

# %%
df.to_csv('POWERLIFTING.csv',index=False)
